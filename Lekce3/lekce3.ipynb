# %% [markdown]
# # 🎯 Lekce 3 – Hash mapy a práce s řetězci
#
#
#
# > **Pokročilé algoritmy a datové struktury** – GitHub Repository
#
#
#
# [![License: MIT](https://img.shields.io/badge/License-MIT-yellow.svg)](https://opensource.org/licenses/MIT)
#
# [![Python 3.8+](https://img.shields.io/badge/python-3.8+-blue.svg)](https://www.python.org/downloads/)
#
# [![LeetCode](https://img.shields.io/badge/practice-LeetCode-orange.svg)](https://leetcode.com/)
#
#
#
# ---
#
#
#
# ## 📚 Úvod do lekce
#
#
#
# Vítej ve třetí lekci kurzu algoritmů! Tentokrát se zaměříme na **hash mapy (slovníky) a práci s řetězci**. Naučíš se rozpoznat situace, kdy je použití `set` nebo `dict` nejefektivnějším řešením.
#
#
#
# ### 🎯 **Cíle lekce:**
#
# - Pochopit, kdy použít hash set vs. hash map
#
# - Naučit se kontrolovat duplicitní hodnoty v poli
#
# - Procvičit porovnávání řetězců a počítání četností znaků
#
# - Analyzovat složitější strukturované vstupy (Sudoku)
#
#
#
# ### 💡 **Klíčové koncepty:**
#
# - Hash set (`set`) a jeho operace v O(1)
#
# - Hash map (`dict`) pro počítání četností
#
# - Normalizace dat pro porovnání řetězců
#
# - Validace maticových struktur pomocí hash map
#
#
#
# ### 🏆 **LeetCode úlohy v této lekci:**
#
# 1. **Contains Duplicate** (Easy)
#
# 2. **Valid Anagram** (Easy)
#
# 3. **Valid Sudoku** (Medium) – BONUS
#
#
#
# ---

# %% [markdown]
# ## 🔍 Úloha 1: Contains Duplicate
#
#
#
# **Obtížnost:** 🟢 Easy | **Časová složitost:** O(n) | **Prostorová složitost:** O(n)
#
#
#
# ### 📋 **Zadání:**
#
# Dostaneš pole celých čísel `nums`. Pokud se v poli **vyskytuje alespoň jedna duplicita**, vrať `True`, jinak `False`.
#
#
#
# ### 💡 **Klíčové pozorování:**
#
# - Nejrychlejší cesta je použít **hash set** a sledovat, zda už jsme prvek viděli
#
# - Alternativou je pole setřídit a hledat po sobě jdoucí duplicity (pomalejší kvůli řazení)
#
#
#
# ### 📊 **Příklady:**
#
#
#
# **Příklad 1:**
#
# ```
#
# Vstup: nums = [1, 2, 3, 1]
#
# Výstup: True
#
# Vysvětlení: Číslo 1 se vyskytuje dvakrát.
#
# ```
#
#
#
# **Příklad 2:**
#
# ```
#
# Vstup: nums = [1, 2, 3, 4]
#
# Výstup: False
#
# Vysvětlení: Všechna čísla jsou unikátní.
#
# ```
#
#
#
# **Příklad 3:**
#
# ```
#
# Vstup: nums = [1,1,1,3,3,4,3,2,4,2]
#
# Výstup: True
#
# ```
#
#
#
# ### 🤔 **Přemýšlej o:**
#
# - Jak zjistíš duplicitu bez vnořených smyček?
#
# - Kolik paměti navíc potřebuje hash set?
#
# - Jaké jsou hraniční případy? (prázdné pole, jedno číslo, všechna stejná čísla)
#
#
#
# ### 💭 **Algoritmus:**
#
# 1. Inicializuj prázdný `set`
#
# 2. Pro každý prvek zkontroluj, zda už je v `set`
#
# 3. Pokud ano, vrať `True`
#
# 4. Pokud projdeme celé pole bez duplicity, vrať `False`

# %%
class Solution(object):

    def containsDuplicate(self, nums):

        """

        :type nums: List[int]

        :rtype: bool

        """

        # TODO: Implementuj své řešení zde

        

        # Nápověda:

        # 1. Inicializuj prázdný set pro sledování viděných hodnot

        # 2. Při průchodu polem ověř, zda je číslo již v setu

        # 3. Pokud ano, vrať True (našli jsme duplicitu)

        # 4. Po průchodu vrať False (žádná duplicita)

        

        pass



# 🧪 Testovací případy

def test_contains_duplicate():

    sol = Solution()

    

    # Test 1: jednoduchá duplicita

    nums1 = [1, 2, 3, 1]

    result1 = sol.containsDuplicate(nums1)

    print(f"Test 1: nums = {nums1}")

    print(f"Výsledek: {result1}, Očekáváno: True")

    print(f"✅ PROŠEL" if result1 is True else "❌ NEPROŠEL")

    print()

    

    # Test 2: žádné duplicity

    nums2 = [1, 2, 3, 4]

    result2 = sol.containsDuplicate(nums2)

    print(f"Test 2: nums = {nums2}")

    print(f"Výsledek: {result2}, Očekáváno: False")

    print(f"✅ PROŠEL" if result2 is False else "❌ NEPROŠEL")

    print()

    

    # Test 3: vícečetné duplicity

    nums3 = [1,1,1,3,3,4,3,2,4,2]

    result3 = sol.containsDuplicate(nums3)

    print(f"Test 3: nums = {nums3}")

    print(f"Výsledek: {result3}, Očekáváno: True")

    print(f"✅ PROŠEL" if result3 is True else "❌ NEPROŠEL")

    print()



# Spusť testy (odkomentuj po implementaci)

# test_contains_duplicate()

# %% [markdown]
# ## 🧮 Úloha 2: Valid Anagram
#
#
#
# **Obtížnost:** 🟢 Easy | **Časová složitost:** O(n) | **Prostorová složitost:** O(1) až O(k)
#
#
#
# ### 📋 **Zadání:**
#
# Dostaneš dva řetězce `s` a `t`. Zjisti, zda je `t` **anagramem** `s`. Anagram znamená, že oba řetězce obsahují stejné znaky ve stejném množství.
#
#
#
# ### 💡 **Klíčové pozorování:**
#
# - Nejrychlejší způsob je použít **počítání četnosti** znaků pomocí slovníku nebo pole
#
# - Řešení pomocí třídění funguje také, ale má složitost O(n log n)
#
#
#
# ### 📊 **Příklady:**
#
#
#
# **Příklad 1:**
#
# ```
#
# Vstup: s = "anagram", t = "nagaram"
#
# Výstup: True
#
# Vysvětlení: Oba řetězce používají stejné znaky.
#
# ```
#
#
#
# **Příklad 2:**
#
# ```
#
# Vstup: s = "rat", t = "car"
#
# Výstup: False
#
# Vysvětlení: Chybí znak "t" a navíc je zde "c".
#
# ```
#
#
#
# **Příklad 3:**
#
# ```
#
# Vstup: s = "áček", t = "kácé"
#
# Výstup: False
#
# Vysvětlení: Diakritika se počítá jako různé znaky.
#
# ```
#
#
#
# ### 🤔 **Přemýšlej o:**
#
# - Jak rychle porovnat četnosti znaků?
#
# - Co když řetězce obsahují unicode znaky nebo různé velikosti písmen?
#
# - Je nutné řešit mezery nebo interpunkci?
#
#
#
# ### 💭 **Algoritmus (hash map přístup):**
#
# 1. Pokud mají různé délky → okamžitě vrať `False`
#
# 2. Inicializuj slovník pro počítání četnosti znaků v `s`
#
# 3. Pro každý znak v `s` zvyš jeho počet, pro `t` jeho počet sniž
#
# 4. Pokud se všechny počty vynulují, řetězce jsou anagramy

# %%
class SolutionValidAnagram(object):

    def isAnagram(self, s, t):

        """

        :type s: str

        :type t: str

        :rtype: bool

        """

        # TODO: Implementuj kontrolu anagramu

        

        # Nápověda:

        # 1. Pokud mají různé délky, vrať False

        # 2. Použij dict (nebo collections.Counter) pro počítání znaků

        # 3. Zvyšuj počty pro s, snižuj pro t

        # 4. Na konci ověř, že všechny hodnoty jsou 0

        

        pass



# 🧪 Testovací případy

def test_valid_anagram():

    sol = SolutionValidAnagram()

    

    # Test 1: jednoduchý anagram

    s1, t1 = "anagram", "nagaram"

    result1 = sol.isAnagram(s1, t1)

    print(f"Test 1: s = '{s1}', t = '{t1}'")

    print(f"Výsledek: {result1}, Očekáváno: True")

    print(f"✅ PROŠEL" if result1 is True else "❌ NEPROŠEL")

    print()

    

    # Test 2: různé znaky

    s2, t2 = "rat", "car"

    result2 = sol.isAnagram(s2, t2)

    print(f"Test 2: s = '{s2}', t = '{t2}'")

    print(f"Výsledek: {result2}, Očekáváno: False")

    print(f"✅ PROŠEL" if result2 is False else "❌ NEPROŠEL")

    print()

    

    # Test 3: unicode znaky

    s3, t3 = "áček", "kácé"

    result3 = sol.isAnagram(s3, t3)

    print(f"Test 3: s = '{s3}', t = '{t3}'")

    print(f"Výsledek: {result3}, Očekáváno: False")

    print(f"✅ PROŠEL" if result3 is False else "❌ NEPROŠEL")

    print()



    # Test 4: velká vs. malá písmena

    s4, t4 = "Listen", "Silent"

    result4 = sol.isAnagram(s4, t4)

    print(f"Test 4: s = '{s4}', t = '{t4}' (bez normalizace)")

    print(f"Výsledek: {result4}, Očekáváno: False")

    print("ℹ️ Tip: Pokud chceš ignorovat velikost písmen, převáděj na lower() před počítáním.")



# Spusť testy (odkomentuj po implementaci)

# test_valid_anagram()

# %% [markdown]
# ---
#
#
#
# ## 🧩 BONUS úloha – Pro pokročilé!
#
#
#
# **Upozornění:** Tato úloha je na úrovni **Medium** a je určena pro ty, kteří zvládli předchozí úlohy a chtějí si vyzkoušet něco náročnějšího!

# %% [markdown]
# ## 🧠 BONUS: Valid Sudoku
#
#
#
# **Obtížnost:** 🟡 Medium | **Časová složitost:** O(9²) = O(1) | **Prostorová složitost:** O(9²)
#
#
#
# ### 📋 **Zadání:**
#
# Máš 9×9 mřížku, která reprezentuje částečně vyplněnou Sudoku hádanku. Platný Sudoku splňuje:
#
#
#
# 1. Každý řádek obsahuje čísla `1-9` maximálně jednou.
#
# 2. Každý sloupec obsahuje čísla `1-9` maximálně jednou.
#
# 3. Každý z devíti 3×3 sub-boxů obsahuje čísla `1-9` maximálně jednou.
#
#
#
# Prázdná pole jsou označena tečkou `'.'`. Ověř, zda je aktuální stav desk y platný.
#
#
#
# ### 📊 **Příklad desky:**
#
# ```
#
# [
#
#   ["5","3",".",".","7",".",".",".","."],
#
#   ["6",".",".","1","9","5",".",".","."],
#
#   [".","9","8",".",".",".",".","6","."],
#
#   ["8",".",".",".","6",".",".",".","3"],
#
#   ["4",".",".","8",".","3",".",".","1"],
#
#   ["7",".",".",".","2",".",".",".","6"],
#
#   [".","6",".",".",".",".","2","8","."],
#
#   [".",".",".","4","1","9",".",".","5"],
#
#   [".",".",".",".","8",".",".","7","9"]
#
# ]
#
# ```
#
#
#
# ### 💡 **Klíčové pozorování:**
#
# - Každý řádek, sloupec i sub-box můžeme kontrolovat pomocí `set`.
#
# - Sub-box můžeme identifikovat pomocí koordinát: `(r // 3, c // 3)`.
#
# - Sudoku má fixní velikost, takže časová složitost je konstantní.
#
#
#
# ### 💭 **Algoritmus:**
#
# 1. Inicializuj tři kolekce (např. slovníky nebo pole setů) pro řádky, sloupce a boxy.
#
# 2. Pro každý neprázdný prvek `board[r][c]` zkontroluj:
#
#    - zda už je v odpovídajícím řádku,
#
#    - zda už je ve sloupci,
#
#    - zda už je v příslušném 3×3 boxu.
#
# 3. Pokud se číslo již vyskytuje, vrať `False`.
#
# 4. Pokud projdeme celou desku bez konfliktu, vrať `True`.
#
#
#
# ### 🤔 **Přemýšlej o:**
#
# - Jak efektivně reprezentovat souběžnou kontrolu řádků, sloupců a boxů?
#
# - Co se stane, když změníme velikost mřížky?
#
# - Jak bys rozšířil řešení na validaci kompletního řešitele Sudoku?

# %%
class SolutionValidSudoku(object):

    def isValidSudoku(self, board):

        """

        :type board: List[List[str]]

        :rtype: bool

        """

        # TODO: Implementuj validaci Sudoku

        

        # Nápověda:

        # 1. Použij tři struktury (např. slovníky s sety) pro řádky, sloupce a 3×3 boxy

        # 2. Ignoruj prázdné buňky označené '.'

        # 3. Index boxu získáš pomocí (row // 3, col // 3)

        # 4. Pokud narazíš na duplicitní číslo v řádku/sloupci/boxu, vrať False

        

        pass



# 🧪 Testovací případy pro BONUS úlohu

def test_valid_sudoku():

    sol = SolutionValidSudoku()

    

    # Test 1: platné Sudoku

    board_valid = [

        ["5","3",".",".","7",".",".",".","."],

        ["6",".",".","1","9","5",".",".","."],

        [".","9","8",".",".",".",".","6","."],

        ["8",".",".",".","6",".",".",".","3"],

        ["4",".",".","8",".","3",".",".","1"],

        ["7",".",".",".","2",".",".",".","6"],

        [".","6",".",".",".",".","2","8","."],

        [".",".",".","4","1","9",".",".","5"],

        [".",".",".",".","8",".",".","7","9"]

    ]

    result1 = sol.isValidSudoku(board_valid)

    print("Test 1: Platná deska")

    print(f"Výsledek: {result1}, Očekáváno: True")

    print(f"✅ PROŠEL" if result1 is True else "❌ NEPROŠEL")

    print()

    

    # Test 2: duplicita v řádku

    board_row_dup = [

        ["8","3",".",".","7",".",".",".","."],

        ["6",".",".","1","9","5",".",".","."],

        [".","9",".",".",".",".",".","6","."],

        ["8",".",".",".","6","8",".",".","3"],  # duplicita "8"

        ["4",".",".","8",".","3",".",".","1"],

        ["7",".",".",".","2",".",".",".","6"],

        [".","6",".",".",".",".","2","8","."],

        [".",".",".","4","1","9",".",".","5"],

        [".",".",".",".","8",".",".","7","9"]

    ]

    result2 = sol.isValidSudoku(board_row_dup)

    print("Test 2: Duplicita v řádku")

    print(f"Výsledek: {result2}, Očekáváno: False")

    print(f"✅ PROŠEL" if result2 is False else "❌ NEPROŠEL")

    print()

    

    # Test 3: duplicita v boxu

    board_box_dup = [

        ["5","3",".",".","7",".",".",".","."],

        ["6",".","3","1","9","5",".",".","."],  # duplicita "3" v boxu (0,0)

        [".","9","8",".",".",".",".","6","."],

        ["8",".",".",".","6",".",".",".","3"],

        ["4",".",".","8",".","3",".",".","1"],

        ["7",".",".",".","2",".",".",".","6"],

        [".","6",".",".",".",".","2","8","."],

        [".",".",".","4","1","9",".",".","5"],

        [".",".",".",".","8",".",".","7","9"]

    ]

    result3 = sol.isValidSudoku(board_box_dup)

    print("Test 3: Duplicita v boxu")

    print(f"Výsledek: {result3}, Očekáváno: False")

    print(f"✅ PROŠEL" if result3 is False else "❌ NEPROŠEL")

    print()



# Spusť testy (odkomentuj po implementaci)

# test_valid_sudoku()

# %% [markdown]
# ---
#
#
#
# ## 📈 Analýza časové složitosti
#
#
#
# ### 🎯 **Porovnání řešení:**
#
#
#
# | Úloha | Naivní přístup | Optimální řešení | Časová složitost |
#
# |-------|---------------|------------------|------------------|
#
# | **Contains Duplicate** | Vnořené smyčky O(n²) | Hash set | O(n) |
#
# | **Valid Anagram** | Řazení obou řetězců | Hash map / Counter | O(n) |
#
# | **Valid Sudoku** | Kontrola každého pravidla zvlášť | Jediný průchod + hash sety | O(1) |
#
#
#
# ### 💡 **Klíčové techniky v této lekci:**
#
#
#
# 1. **🔁 Hash Set Lookup** – detekce duplicity v konstantním čase.
#
# 2. **🧮 Počítání četností** – slovníky/Counter pro porovnávání řetězců.
#
# 3. **🧱 Mapování na klíč** – kombinace indexů `(row, col, box)` pro Sudoku.
#
# 4. **🧹 Normalizace vstupu** – práce s velikostí písmen, diakritikou a unicode znaky.
#
#
#
# ---
#
#
#
# ## 🎯 Shrnutí a další kroky
#
#
#
# ### ✅ **Co jsi se naučil:**
#
# - Vyhodnocovat situace, kdy se hodí `set` vs. `dict`.
#
# - Implementovat rychlou identifikaci duplicit v datech.
#
# - Porovnávat řetězce pomocí počítání znaků.
#
# - Validovat složitější struktury kombinací více hash map.
#
#
#
# ### 🚀 **Doporučené další úlohy na LeetCode:**
#
# - **Easy:** [Two Sum](https://leetcode.com/problems/two-sum/), [Happy Number](https://leetcode.com/problems/happy-number/)
#
# - **Medium:** [Group Anagrams](https://leetcode.com/problems/group-anagrams/), [Longest Substring Without Repeating Characters](https://leetcode.com/problems/longest-substring-without-repeating-characters/)
#
#
#
# ### 📚 **Pokračování v kurzu:**
#
# - **Lekce 4:** Two Pointers a Sliding Window v praxi
#
# - **Lekce 5:** Problemy s prefix součty a kumulativními strukturami
#
#
#
# ---
#
#
#
# *Pokračuj v tréninku – konzistentní praxe s hash mapami výrazně zrychlí řešení pohovorových úloh! 💪*
